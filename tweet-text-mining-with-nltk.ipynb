# %% [markdown]
# <a href="https://www.kaggle.com/code/gabrielluizone/tweet-text-mining-with-nltk?scriptVersionId=176281618" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ## Tweet Text Mining
# > Using Tweets for text mining with nltk
#
# ---
# - Curpus dos tweets
# - Leitura `RAW` dos textos
# - Seleção de palavras
# - Remoção de stopwords
# - Visualização & Frequência

# %%
# Importação das bibliotecas
from nltk.corpus import PlaintextCorpusReader # Leitor de corpus especificos para o texto
from nltk.corpus import stopwords
import nltk

# Formatação & Markdown
from IPython.display import Markdown as md

import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from wordcloud import WordCloud
import string

nltk.download('stopwords');
# Out:
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Criação de um corpus lendo os arquivos
corpus = PlaintextCorpusReader('/kaggle/input/text-mining-one', '.*', encoding = "ISO-8859-1")

# Leitura dos arquivos e percorrer os registros e seus nomes
files = corpus.fileids()
files[:7]
# Out:
# ['1.txt', '10.txt', '100.txt', '1000.txt', '1001.txt', '1002.txt', '1003.txt']

# %%
# Acesso ao arquivo em especifico
text = corpus.raw(files[0])
display(text)

# Acesso a todas as palavras de todos os arquivos
alltext = corpus.raw()
allword = corpus.words()
# Out:
# "@relation 'Reuters-21578 Corn ModApte Train-weka.filters.unsupervised.attribute.NumericToBinary-weka.filters.unsupervised.instance.RemoveFolds-S0-N5-F1'\r\n"

# %%
# Stopwords em Inglês
stops = stopwords.words('english')
#stops = stopwords.words('portuguese')

# %%
# Definição das cores que serão utilizadas na nuvem de palavras
mapa_cores = ListedColormap(['#d45757', # Vermelho
                             '#5787d4', # Azul
                             '#57d480', # Verde
                             '#d4a057' # Laranja
])

# Criação da nuvem de palavras, com no máximo 100 palavras e utilizando as stop words
cloud = WordCloud(background_color = '#202124',
                  colormap = mapa_cores,
                  stopwords = stops,
                  max_words = 100)

# Criação e visualização da nuvem de palavras
cloud.generate(alltext)

plt.figure(figsize=(20,10), dpi=300)
plt.imshow(cloud);

# %%
words_without_punctuation = [word for word in allword if (word not in stops) and (word not in string.punctuation)]
freq = nltk.FreqDist(words_without_punctuation)
freq
# Out:
# FreqDist({'said': 3398, 'mln': 2721, '3': 2228, 'vs': 2194, '0': 1949, 'dlrs': 1945, '1': 1661, '000': 1640, '&#': 1466, ";',": 1432, ...})

# %%
freq.most_common(100)
# Out:
# [('said', 3398),
#  ('mln', 2721),
#  ('3', 2228),
#  ('vs', 2194),
#  ('0', 1949),
#  ('dlrs', 1945),
#  ('1', 1661),
#  ('000', 1640),
#  ('&#', 1466),
#  (";',", 1432),
#  ('The', 1429),
#  ('cts', 1374),
#  ('lt', 1286),
#  ('Reuter', 1214),
#  ('pct', 1146),
#  ('2', 1001),
#  ('year', 878),
#  ('U', 833),
#  ('loss', 800),
#  ('S', 794),
#  ('billion', 707),
#  ('5', 674),
#  ('1986', 666),
#  ('would', 638),
#  ('4', 633),
#  ('company', 518),
#  ('share', 513),
#  ('6', 505),
#  ('profit', 498),
#  ('Net', 486),
#  ('7', 469),
#  ('Shr', 456),
#  ('8', 440),
#  ('March', 439),
#  ('net', 401),
#  ('9', 393),
#  ('Revs', 392),
#  ('one', 390),
#  ('Inc', 385),
#  ('last', 380),
#  ('tonnes', 361),
#  ('market', 357),
#  ('also', 355),
#  ('shares', 351),
#  ('per', 347),
#  ('two', 340),
#  ('stock', 339),
#  ('oil', 328),
#  ('prices', 325),
#  ('10', 315),
#  ('1985', 309),
#  ('QTR', 300),
#  ('1987', 298),
#  ('31', 295),
#  ('It', 294),
#  ('trade', 290),
# ...
